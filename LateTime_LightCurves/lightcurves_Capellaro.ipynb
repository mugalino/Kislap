# %% [markdown]
# # Light Curve Plotter for the Nebular Phase (Capellaro et al 1997)

# %% [markdown]
# This code was used for Kosakowski et al (2022) to calculate the luminosity of type Ia events 2011fe and 2019ehk. I revised this to automatically add new colors for additional isotopes. This could account for the radioactive decay of several isotopes using the Bateman equation solution,
#
# \begin{equation}
#     L(t) = M(A)\ \varepsilon_A\  e^{-\lambda_A t}
# \end{equation}
#
# where $M(A)$ is the total mass abundance of isotope with baryon number $A$, $\varepsilon_A$ is the specific decay energy rate, and $\lambda_A$ is the decay timescale.

# %%
# Importing a custom module light_curves, which may be modified by 
# opening the light_curves.py in the same directory

from light_curves import *

# %%
# These are the isotopes that will be included in the light curve 
isotopes = [ \
        "ni56",\
        "co56",\
        "co57",\
        "fe55",\
        "ti44"
        ]
# For 11fe, uncomment all isotopes
# For 19ehk, comment out all isotopes except co56 and ti44

# Identify the event that you wish to analyze
event = "11fe"
curve_plotter(np.linspace(1000., 20000.0, 100), isotopes, event, None)
# Out:
# /home/mark-ugalino/research_codes/CoCo/LateTime_LightCurves/light_curves.py:117: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   total = np.sum(np.array(lum_list),0)

# %%
isotopes = [ \
        #"ni56",\
        "co56",\
        #"co57",\
        #"fe55",\
        "ti44"
        ]
event = "19ehk"
curve_plotter(np.linspace(100., 1000.0, 100), isotopes, event, None)
