# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = np.loadtxt('profile.txt')

# %%
radius = data.T[0] / 1.e5;
density = data.T[1];
pressure = data.T[2];
mass = data.T[3] / 1.989e33;

# %%
plt.plot(radius, mass);
